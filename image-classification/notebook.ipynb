# %% [markdown]
# ## [today] Code testing

# %% [markdown]
# ## [2021-09-09] Multi-Classification

# %% [markdown]
# ### Input variables

# %%
import os 
import sys
from lib import Autils_classification
from lib.networks import Net

# %% [markdown]
# ### Train a model

# %%
# !python train.py --cfg config/config.yml --gpu 0-3
# Out:
# crossEntropy
# Workspace = data/workspace/data_NVS-proj/
# model_path = model/data_NVS-proj/2D_CNN-MClss_cpu.pth
# data folder = data/NVS-proj
# model folder = model/data_NVS-proj/
# device = cpu
# data_dict =  {'CS01 - Simulation Tool dataset': [], 'CS02 - Missing #1 Simulation Tool dataset': [], 'CS03 - Missing #2 Simulation Tool dataset': [], 'CS04 - missingparts-1 2D': [], 'CS06 - missingparts-3 2D': []}
# classes= ['CS01 - Simulation Tool dataset', 'CS02 - Missing #1 Simulation Tool dataset', 'CS03 - Missing #2 Simulation Tool dataset', 'CS04 - missingparts-1 2D', 'CS06 - missingparts-3 2D']
# sep_OS= \
# data_paths[0]= CS01 - Simulation Tool dataset\Tool_noScatter_0000.tif
# sub_folder =  CS01 - Simulation Tool dataset
# sub_folder =  CS01 - Simulation Tool dataset
# sub_folder =  CS01 - Simulation Tool dataset
# sub_folder =  CS01 - Simulation Tool dataset
# sub_folder =  CS01 - Simulation Tool dataset
# sub_folder =  CS01 - Simulation Tool dataset
# ...

# %% [markdown]
# ### Deploy the model

# %%
# !python deploy.py --model model/data_NVS-proj/2D_CNN-MClss_cpu.pth  --data data/deploy
# Out:
# image size = <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128 at 0x20380A70700>
# data/deploy\CS01 - Simulation Tool dataset_Tool_noScatter_0005.jpg
# Figure(640x480)
# image size = <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128 at 0x20380B641C0>
# data/deploy\CS04 - missingparts-1 2D_Tool_0000.jpg
# Figure(640x480)
# image size = <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128 at 0x20380B96F70>
# data/deploy\CS06 - missingparts-3 2D_Tool_0000.jpg
# Figure(640x480)
#
#  prediction results :
#                                                  file                      prediction
# 0  data/deploy\CS01 - Simulation Tool dataset_Too...  CS01 - Simulation Tool dataset
# 1  data/deploy\CS04 - missingparts-1 2D_Tool_0000...        CS04 - missingparts-1 2D
# 2  data/deploy\CS06 - missingparts-3 2D_Tool_0000...        CS06 - missingparts-3 2D
# ...
